# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings("ignore")

# %%
#load datsets
df=pd.read_csv("C:\\Users\\HP\\Downloads\\yellow_tripdata_2020-09.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed:_0  VendorID tpep_pickup_datetime  \
# 0           0           0       1.0  2020-09-01 07:37:32
# 1           1           1       2.0  2020-09-01 07:47:57
# 2           2           2       2.0  2020-09-01 09:02:30
# 3           3           3       1.0  2020-09-01 09:00:28
# 4           4           4       2.0  2020-09-01 10:55:27
#
#   tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0   2020-09-01 07:42:12              1.0           0.90         1.0
# 1   2020-09-01 07:52:30              1.0           0.87         1.0
# 2   2020-09-01 09:14:01              1.0           2.33         1.0
# 3   2020-09-01 09:07:20              1.0           1.30         1.0
# 4   2020-09-01 11:06:12              1.0           4.93         1.0
#
#   store_and_fwd_flag  PULocationID  DOLocationID  payment_type  fare_amount  \
# 0                  N           140           262           1.0          5.5
# 1                  N            48           230           1.0          5.5
# 2                  N           238            43           2.0         11.0
# 3                  N           142           163           1.0          7.0
# 4                  N            88           170           1.0         15.5
#
#    extra  mta_tax  tip_amount  tolls_amount  improvement_surcharge  \
# 0    2.5      0.5        1.75           0.0                    0.3
# 1    0.0      0.5        1.20           0.0                    0.3
# 2    0.0      0.5        0.00           0.0                    0.3
# 3    2.5      0.5        2.00           0.0                    0.3
# 4    0.0      0.5        2.50           0.0                    0.3
#
#    total_amount  congestion_surcharge
# 0         10.55                   2.5
# 1         10.00                   2.5
# 2         14.30                   2.5
# 3         12.30                   2.5
# 4         21.30                   2.5

# %%
#Exploratray Data analysis
df.shape
# Out:
# (998, 20)

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# Unnamed:_0                 int64
# VendorID                 float64
# tpep_pickup_datetime      object
# tpep_dropoff_datetime     object
# passenger_count          float64
# trip_distance            float64
# RatecodeID               float64
# store_and_fwd_flag        object
# PULocationID               int64
# DOLocationID               int64
# payment_type             float64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# improvement_surcharge    float64
# total_amount             float64
# congestion_surcharge     float64
# dtype: object

# %%
df["tpep_pickup_datetime"]=pd.to_datetime(df["tpep_pickup_datetime"])
df["tpep_dropoff_datetime"]=pd.to_datetime(df["tpep_dropoff_datetime"])

# %%
df["duration"]=df["tpep_dropoff_datetime"]-df["tpep_pickup_datetime"]
df["duration"].dt.total_seconds()/60
# Out:
# 0       4.666667
# 1       4.550000
# 2      11.516667
# 3       6.866667
# 4      10.750000
#          ...
# 993    22.000000
# 994    10.000000
# 995    -0.483333
# 996    25.100000
# 997    12.000000
# Name: duration, Length: 998, dtype: float64

# %%
df
# Out:
#      Unnamed: 0  Unnamed:_0  VendorID tpep_pickup_datetime  \
# 0             0           0       1.0  2020-09-01 07:37:32
# 1             1           1       2.0  2020-09-01 07:47:57
# 2             2           2       2.0  2020-09-01 09:02:30
# 3             3           3       1.0  2020-09-01 09:00:28
# 4             4           4       2.0  2020-09-01 10:55:27
# ..          ...         ...       ...                  ...
# 993         993         993       NaN  2020-09-29 06:58:00
# 994         994         994       NaN  2020-09-30 11:49:00
# 995         995         995       NaN  2020-09-29 07:09:37
# 996         996         996       NaN  2020-09-09 18:23:37
# 997         997         997       NaN  2020-09-10 09:03:00
#
#     tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0     2020-09-01 07:42:12              1.0           0.90         1.0
# 1     2020-09-01 07:52:30              1.0           0.87         1.0
# 2     2020-09-01 09:14:01              1.0           2.33         1.0
# 3     2020-09-01 09:07:20              1.0           1.30         1.0
# 4     2020-09-01 11:06:12              1.0           4.93         1.0
# ..                    ...              ...            ...         ...
# 993   2020-09-29 07:20:00              NaN           9.54         NaN
# 994   2020-09-30 11:59:00              NaN           1.35         NaN
# 995   2020-09-29 07:09:08              NaN           4.04         NaN
# 996   2020-09-09 18:48:43              NaN           6.38         NaN
# 997   2020-09-10 09:15:00              NaN           2.56         NaN
#
#     store_and_fwd_flag  PULocationID  ...  payment_type  fare_amount  extra  \
# 0                    N           140  ...           1.0         5.50    2.5
# 1                    N            48  ...           1.0         5.50    0.0
# 2                    N           238  ...           2.0        11.00    0.0
# 3                    N           142  ...           1.0         7.00    2.5
# 4                    N            88  ...           1.0        15.50    0.0
# ..                 ...           ...  ...           ...          ...    ...
# 993                NaN            45  ...           NaN        25.98    0.0
# 994                NaN            92  ...           NaN        11.45    0.0
# 995                NaN           265  ...           NaN        17.02    0.0
# 996                NaN           157  ...           NaN        33.52    0.0
# 997                NaN           148  ...           NaN        13.40    0.0
#
#      mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0        0.5        1.75          0.00                    0.3         10.55
# 1        0.5        1.20          0.00                    0.3         10.00
# 2        0.5        0.00          0.00                    0.3         14.30
# 3        0.5        2.00          0.00                    0.3         12.30
# 4        0.5        2.50          0.00                    0.3         21.30
# ..       ...         ...           ...                    ...           ...
# 993      0.5        2.75          6.12                    0.3         35.65
# 994      0.5        2.75          0.00                    0.3         15.00
# 995      0.5        0.00          0.00                    0.3         17.82
# 996      0.5        2.75          0.00                    0.3         37.07
# 997      0.5        3.70          0.00                    0.3         20.40
#
#      congestion_surcharge          duration
# 0                     2.5   0 days 00:04:40
# 1                     2.5   0 days 00:04:33
# 2                     2.5   0 days 00:11:31
# 3                     2.5   0 days 00:06:52
# 4                     2.5   0 days 00:10:45
# ..                    ...               ...
# 993                   0.0   0 days 00:22:00
# 994                   0.0   0 days 00:10:00
# 995                   0.0 -1 days +23:59:31
# 996                   0.0   0 days 00:25:06
# 997                   2.5   0 days 00:12:00
#
# [998 rows x 21 columns]

# %%
#filtering data
df=df[["passenger_count","payment_type","fare_amount","trip_distance","duration"]]
df
# Out:
#      passenger_count  payment_type  fare_amount  trip_distance  \
# 0                1.0           1.0         5.50           0.90
# 1                1.0           1.0         5.50           0.87
# 2                1.0           2.0        11.00           2.33
# 3                1.0           1.0         7.00           1.30
# 4                1.0           1.0        15.50           4.93
# ..               ...           ...          ...            ...
# 993              NaN           NaN        25.98           9.54
# 994              NaN           NaN        11.45           1.35
# 995              NaN           NaN        17.02           4.04
# 996              NaN           NaN        33.52           6.38
# 997              NaN           NaN        13.40           2.56
#
#              duration
# 0     0 days 00:04:40
# 1     0 days 00:04:33
# 2     0 days 00:11:31
# 3     0 days 00:06:52
# 4     0 days 00:10:45
# ..                ...
# 993   0 days 00:22:00
# 994   0 days 00:10:00
# 995 -1 days +23:59:31
# 996   0 days 00:25:06
# 997   0 days 00:12:00
#
# [998 rows x 5 columns]

# %%
#check missing value
df.isnull().sum()
# Out:
# passenger_count    69
# payment_type       69
# fare_amount         0
# trip_distance       0
# duration            0
# dtype: int64

# %%
 (69/len(df)*100)
# Out:
# 6.913827655310621

# %%
df.dropna(inplace=True)
df
# Out:
#      passenger_count  payment_type  fare_amount  trip_distance        duration
# 0                1.0           1.0          5.5           0.90 0 days 00:04:40
# 1                1.0           1.0          5.5           0.87 0 days 00:04:33
# 2                1.0           2.0         11.0           2.33 0 days 00:11:31
# 3                1.0           1.0          7.0           1.30 0 days 00:06:52
# 4                1.0           1.0         15.5           4.93 0 days 00:10:45
# ..               ...           ...          ...            ...             ...
# 924              4.0           2.0         12.5           3.00 0 days 00:15:17
# 925              1.0           2.0          8.5           1.98 0 days 00:07:35
# 926              1.0           1.0          5.0           0.91 0 days 00:03:42
# 927              1.0           1.0         11.0           3.15 0 days 00:09:27
# 928              1.0           2.0          9.5           2.10 0 days 00:10:13
#
# [929 rows x 5 columns]

# %%
df["passenger_count"]=df["passenger_count"].astype("int64")
df["payment_type"]=df["payment_type"].astype("int64")

# %%
df[df.duplicated()]
df
# Out:
#      passenger_count  payment_type  fare_amount  trip_distance        duration
# 0                  1             1          5.5           0.90 0 days 00:04:40
# 1                  1             1          5.5           0.87 0 days 00:04:33
# 2                  1             2         11.0           2.33 0 days 00:11:31
# 3                  1             1          7.0           1.30 0 days 00:06:52
# 4                  1             1         15.5           4.93 0 days 00:10:45
# ..               ...           ...          ...            ...             ...
# 924                4             2         12.5           3.00 0 days 00:15:17
# 925                1             2          8.5           1.98 0 days 00:07:35
# 926                1             1          5.0           0.91 0 days 00:03:42
# 927                1             1         11.0           3.15 0 days 00:09:27
# 928                1             2          9.5           2.10 0 days 00:10:13
#
# [929 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
#data distribution or contribution
df["passenger_count"].value_counts(normalize=True)
# Out:
# passenger_count
# 1    0.750000
# 2    0.140086
# 3    0.029095
# 5    0.026940
# 4    0.020474
# 6    0.020474
# 0    0.012931
# Name: proportion, dtype: float64

# %%
df["payment_type"].value_counts(normalize=True)
# Out:
# payment_type
# 1    0.712284
# 2    0.275862
# 3    0.008621
# 4    0.003233
# Name: proportion, dtype: float64

# %%
df=df[df["payment_type"]<3]
df=df[(df["passenger_count"]>0)&(df["passenger_count"]<6)]

# %%
df.shape
# Out:
# (887, 5)

# %%
df["payment_type"].replace([1,2],['Card','Cash'], inplace = True)

# %%
df.describe()
# Out:
#        passenger_count  fare_amount  trip_distance                   duration
# count       887.000000   887.000000     887.000000                        887
# mean          1.379932    10.657272       2.431172  0 days 00:19:22.277339346
# std           0.870227     8.501169       2.858909  0 days 01:42:20.360185295
# min           1.000000    -4.000000       0.000000            0 days 00:00:00
# 25%           1.000000     6.000000       0.980000     0 days 00:05:41.500000
# 50%           1.000000     8.500000       1.600000            0 days 00:09:01
# 75%           1.000000    12.000000       2.700000            0 days 00:13:48
# max           5.000000   100.000000      27.330000            0 days 23:38:53

# %%
df=df[df["passenger_count"]>0]
df=df[df["fare_amount"]>0]
df=df[df["trip_distance"]>0]

# %%
df
# Out:
#      passenger_count payment_type  fare_amount  trip_distance        duration
# 0                  1         Card          5.5           0.90 0 days 00:04:40
# 1                  1         Card          5.5           0.87 0 days 00:04:33
# 2                  1         Cash         11.0           2.33 0 days 00:11:31
# 3                  1         Card          7.0           1.30 0 days 00:06:52
# 4                  1         Card         15.5           4.93 0 days 00:10:45
# ..               ...          ...          ...            ...             ...
# 924                4         Cash         12.5           3.00 0 days 00:15:17
# 925                1         Cash          8.5           1.98 0 days 00:07:35
# 926                1         Card          5.0           0.91 0 days 00:03:42
# 927                1         Card         11.0           3.15 0 days 00:09:27
# 928                1         Cash          9.5           2.10 0 days 00:10:13
#
# [879 rows x 5 columns]

# %%
plt.boxplot(df["fare_amount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x236b8144bf0>,
#   <matplotlib.lines.Line2D at 0x236b81457f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x236b81441d0>,
#   <matplotlib.lines.Line2D at 0x236b81455b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x236b810bb90>],
#  'medians': [<matplotlib.lines.Line2D at 0x236b8147e60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x236b8144830>],
#  'means': []}

# %%
#using IQR 
for col in ['fare_amount','trip_distance','duration']:
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    IQR=q3-q1
    
    lower_bound = q1-1.5*IQR
    upper_bound = q3+1.5*IQR
    
    df=df[(df[col]>=lower_bound)&(df[col]<=upper_bound)]

# %%
df
# Out:
#      passenger_count payment_type  fare_amount  trip_distance        duration
# 0                  1         Card          5.5           0.90 0 days 00:04:40
# 1                  1         Card          5.5           0.87 0 days 00:04:33
# 2                  1         Cash         11.0           2.33 0 days 00:11:31
# 3                  1         Card          7.0           1.30 0 days 00:06:52
# 5                  1         Card          8.0           1.61 0 days 00:09:19
# ..               ...          ...          ...            ...             ...
# 924                4         Cash         12.5           3.00 0 days 00:15:17
# 925                1         Cash          8.5           1.98 0 days 00:07:35
# 926                1         Card          5.0           0.91 0 days 00:03:42
# 927                1         Card         11.0           3.15 0 days 00:09:27
# 928                1         Cash          9.5           2.10 0 days 00:10:13
#
# [752 rows x 5 columns]

# %%
plt.hist(df["fare_amount"])
# Out:
# (array([ 23., 125., 141., 149.,  81.,  88.,  58.,  52.,  23.,  12.]),
#  array([ 2.5,  3.9,  5.3,  6.7,  8.1,  9.5, 10.9, 12.3, 13.7, 15.1, 16.5]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title("Distribution of fare amount")
plt.hist(df[df["payment_type"]=="Card"]["fare_amount"],histtype="barstacked",bins=20,edgecolor="k",color="#FA643F",label="Card")
plt.hist(df[df["payment_type"]=="Cash"]["fare_amount"],histtype="barstacked",bins=20,edgecolor="k",color="#FFBCAB",label="Cash")
plt.legend()
plt.show
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.title("Distribution of trip distance")
plt.hist(df[df["payment_type"]=="Card"]["trip_distance"],histtype="barstacked",bins=20,edgecolor="k",color="#FA643F",label="Card")
plt.hist(df[df["payment_type"]=="Cash"]["trip_distance"],histtype="barstacked",bins=20,edgecolor="k",color="#FFBCAB",label="Cash")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#using groupby
df.groupby("payment_type").agg({"fare_amount":["mean","std"],"trip_distance":["mean","std"]})

# %%
plt.title("Preference of payment Type")
plt.pie(df["payment_type"].value_counts(normalize=True),labels = df["payment_type"].value_counts().index,
       startangle=90,shadow=True,autopct="%1.1f%%",colors=["#FA643F","#FFBCAB"])
plt.show()

# %%
passenger_count=df.groupby(["payment_type","passenger_count"])[["passenger_count"]].count()
passenger_count.rename(columns = {"passenger_count":"count"},inplace=True)
passenger_count.reset_index(inplace=True)

# %%
passenger_count["perc"] = (passenger_count["count"]/passenger_count["count"].sum())*100

# %%
passenger_count
# Out:
#   payment_type  passenger_count  count       perc
# 0         Card                1    417  55.452128
# 1         Card                2     79  10.505319
# 2         Card                3     20   2.659574
# 3         Card                4     11   1.462766
# 4         Card                5     14   1.861702
# 5         Cash                1    165  21.941489
# 6         Cash                2     31   4.122340
# 7         Cash                3      6   0.797872
# 8         Cash                4      5   0.664894
# 9         Cash                5      4   0.531915

# %%
df=pd.DataFrame(columns=["payment_type",1,2,3,4,5])
df["payment_type"]=["Card","Cash"]
df.iloc[0,1:]=passenger_count.iloc[0:5,-1]
df.iloc[1,1:]=passenger_count.iloc[5,-1]
df
# Out:
#   payment_type          1          2          3          4          5
# 0         Card  55.452128  10.505319   2.659574   1.462766   1.861702
# 1         Cash  21.941489  21.941489  21.941489  21.941489  21.941489

# %%
df.plot(x="payment_type",kind="barh",stacked = True,color= ["#FA643F" ,"#FFBCAB","#CBB2B2","#F1F1F1","#FD9F9F"])
#ADD PERCENTAGE TEXT
for p in ax.patches:
    width = p.get_width()
    height=p.get_height()
    x,y=p.get_xy()
    ax.text(x+width/2,
            y+ height/2,
            "{:.0f}%".format(width),
             horizontalalignment="center",
             verticalalignment="center")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[201], line 3
#       1 df.plot(x="payment_type",kind="barh",stacked = True,color= ["#FA643F" ,"#FFBCAB","#CBB2B2","#F1F1F1","#FD9F9F"])
#       2 #ADD PERCENTAGE TEXT
# ----> 3 for p in ax.patches:
#       4     width = p.get_width()
#       5     height=p.get_height()
#
# NameError: name 'ax' is not defined
